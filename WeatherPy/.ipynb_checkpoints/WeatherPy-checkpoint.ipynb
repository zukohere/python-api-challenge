# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
# enter user's key into api_key file
from api_keys import weather_api_key
if weather_api_key == "YOUR KEY HERE!":
    import sys
    path = "/Users/matth/Desktop"
    sys.path.insert(0, path)
    from API_Keys import api_key
    weather_api_key= api_key["https://openweathermap.org/"]

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#import pretty print
import pprint as pprint

#for date title in plots and filenames
from datetime import date

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?" 
#build url with a few other params, api key, and units imperial for temp in F and windspeed in mph.
query_url = base_url + "appid=" + weather_api_key +"&units=imperial&q="

# %%
#set min number of cities needed
citymin = 500



# initialize lists for data storage
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
Date = []
Lat=[]
Long=[]
# include a list of cities that error out.
city_not_found=[]
#initialize count how many cities we've found weather data for.
citycount=0
#check if we have enough cities, if not, abort. if so, proceed to for loop.
if len(cities)<citymin:
    print("-----------------------------")
    print(f"Data Retrieval Aborted.")
    print(f"Rerun Generate Cities List to ensure >{citymin} cities.")
    print("-----------------------------")
else:
    print("Beginning Data Retrieval")     
    print("-----------------------------")
    #begin for loop to store records for each city
    for city in cities:
        try:
            city_url = query_url + city
            response = requests.get(city_url).json()
            # Add a one second interval between queries to (hopefully) stay within API query limits
            time.sleep(1)
            # Use response to generate lists.
            Max_Temp.append(response["main"]["temp_max"]) 
            Humidity.append(response["main"]["humidity"])
            Cloudiness.append(response["clouds"]["all"])
            Wind_Speed.append(response["wind"]["speed"])
            Country.append(response["sys"]["country"])
            Date.append(response["dt"])
            Lat.append(response["coord"]["lat"])
            Long.append(response["coord"]["lon"])
            citycount=citycount+1
            print(f"processing record number {citycount} for | {city}")
        except:
            print(f"City: {city} not found. Marking as NaN...")
            Max_Temp.append(float("NaN")) 
            Humidity.append(float("NaN"))
            Cloudiness.append(float("NaN"))
            Wind_Speed.append(float("NaN"))
            Country.append(float("NaN"))
            Date.append(float("NaN"))
            Lat.append(float("NaN"))
            Long.append(float("NaN"))
            city_not_found.append(city)
    #end for loop, print summary.      
    print("-----------------------------")
    print("Data Retrieval Complete")  
    print(f"Records for {citycount} cities created.")
    print(f"{len(city_not_found)} cities not found and skipped. See list: city_not_found for details.")
    print("-----------------------------")
    if citycount<citymin:
        print(f"Warning: Though more than {citymin} cities were input,")
        print(f"only {citycount} cities have corresponding weather data.")
        print(f"Consider reruning from Generate Cities to boost count.")
# Out:
# Beginning Data Retrieval
# -----------------------------
# processing record number 1 for | east london
# processing record number 2 for | grindavik
# processing record number 3 for | mataura
# City: tumannyy not found. Marking as NaN...
# processing record number 4 for | vila franca do campo
# processing record number 5 for | santa marta
# processing record number 6 for | shambu
# processing record number 7 for | bluff
# City: taolanaro not found. Marking as NaN...
# processing record number 8 for | yellowknife
# processing record number 9 for | busselton
# processing record number 10 for | nikolskoye
# processing record number 11 for | upernavik
# City: meyungs not found. Marking as NaN...
# processing record number 12 for | tiksi
# City: mys shmidta not found. Marking as NaN...
# processing record number 13 for | raton
# processing record number 459 for | shawville
# processing record number 460 for | bennington
# processing record number 461 for | stornoway
# processing record number 462 for | yingcheng
# processing record number 463 for | omsukchan
# processing record number 464 for | san juan tepa
# processing record number 465 for | colac
# processing record number 466 for | ecoporanga
# processing record number 467 for | azare
# processing record number 468 for | tiarei
# processing record number 469 for | nkawkaw
# processing record number 470 for | bandarbeyla
# processing record number 471 for | lahaina
# processing record number 472 for | jacqueville
# processing record number 473 for | bumba
# processing record number 474 for | termoli
# processing record number 475 for | yuancheng
# processing record number 476 for | talipparamba
# processing record number 477 for | palauig
# processing record number 478 for | hastings
# processing record number 479 for | penzance
# processing record number 480 for | petropavlovsk-kamchatskiy
# processing record number 481 for | esmeraldas
# processing record number 482 for | yulara
# processing record number 483 for | clyde river
# processing record number 484 for | narasapur
# processing record number 485 for | anito
# processing record number 486 for | antalaha
# processing record number 487 for | lander
# processing record number 488 for | raudeberg
# processing record number 489 for | port hardy
# City: rawannawi not found. Marking as NaN...
# processing record number 490 for | kumluca
# processing record number 491 for | treuchtlingen
# processing record number 492 for | dom pedro
# processing record number 493 for | abu zabad
# processing record number 494 for | te anau
# processing record number 495 for | tromso
# processing record number 496 for | karratha
# processing record number 497 for | faya
# processing record number 498 for | berlevag
# processing record number 499 for | chadan
# processing record number 500 for | ola
# processing record number 501 for | antofagasta
# processing record number 502 for | beringovskiy
# processing record number 503 for | mariental
# processing record number 504 for | matamoros
# processing record number 505 for | bacolod
# processing record number 506 for | olga
# processing record number 507 for | coahuayana
# processing record number 508 for | dhar
# processing record number 509 for | bontang
# processing record number 510 for | isla mujeres
# processing record number 511 for | sept-iles
# processing record number 512 for | casper
# City: afgoye not found. Marking as NaN...
# processing record number 513 for | santiago
# processing record number 514 for | praia da vitoria
# processing record number 515 for | brigantine
# processing record number 516 for | alekseyevsk
# processing record number 517 for | huarmey
# City: mullaitivu not found. Marking as NaN...
# processing record number 518 for | safakulevo
# processing record number 519 for | fare
# processing record number 520 for | brookhaven
# processing record number 521 for | mayo
# City: ijaki not found. Marking as NaN...
# processing record number 522 for | marin
# processing record number 523 for | makurdi
# processing record number 524 for | kasempa
# City: nizhneyansk not found. Marking as NaN...
# processing record number 525 for | goldsboro
# processing record number 526 for | safaga
# processing record number 527 for | lodeynoye pole
# processing record number 528 for | burnie
# processing record number 529 for | paragominas
# processing record number 530 for | nexo
# processing record number 531 for | ouango
# processing record number 532 for | shetpe
# processing record number 533 for | yining
# processing record number 534 for | timelkam
# processing record number 535 for | usinsk
# processing record number 536 for | krasnyy yar
# processing record number 537 for | albanel
# processing record number 538 for | bereda
# processing record number 539 for | keuruu
# processing record number 540 for | mandal
# processing record number 541 for | korla
# processing record number 542 for | mogadishu
# processing record number 543 for | carpina
# City: felidhoo not found. Marking as NaN...
# processing record number 544 for | brewster
# processing record number 545 for | clearwater
# processing record number 546 for | niquelandia
# processing record number 547 for | half moon bay
# processing record number 548 for | srednekolymsk
# processing record number 549 for | ilheus
# processing record number 550 for | newport
# processing record number 551 for | ede
# processing record number 552 for | eidfjord
# processing record number 553 for | rawah
# processing record number 554 for | pitiquito
# processing record number 555 for | spijkenisse
# processing record number 556 for | slave lake
# processing record number 557 for | panaba
# processing record number 558 for | shelburne
# processing record number 559 for | dese
# processing record number 560 for | hirara
# processing record number 561 for | bafoulabe
# processing record number 562 for | killybegs
# processing record number 563 for | maceio
# -----------------------------
# Data Retrieval Complete
# Records for 563 cities created.
# 46 cities not found and skipped. See list: city_not_found for details.
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_city= {"City": cities,
               "Lat": Lat,
               "Lng": Long,
               "Max Temp": Max_Temp,
               "Humidity": Humidity,
               "Cloudiness": Cloudiness,
               "Wind Speed": Wind_Speed,
               "Country": Country,
               "Date": Date}
# this line drops any cities that could not be found, which were marked as NaN
weather_city_df = pd.DataFrame(weather_city).dropna(how="any").reset_index(drop=True)
# view the dataframe, able to confirm row counts against the printout above.
weather_city_df
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             east london -33.0153   27.9116     71.73      86.0        98.0
# 1               grindavik  63.8424  -22.4338     33.80      93.0        90.0
# 2                 mataura -46.1927  168.8643     55.00      94.0       100.0
# 3    vila franca do campo  37.7167  -25.4333     59.00      88.0        75.0
# 4             santa marta  11.2408  -74.1990     86.00      59.0        88.0
# ..                    ...      ...       ...       ...       ...         ...
# 558                  dese  11.1333   39.6333     54.75      56.0         6.0
# 559                hirara  24.8000  125.2833     68.00      82.0        40.0
# 560             bafoulabe  13.8065  -10.8321     84.09      15.0         0.0
# 561             killybegs  54.6333   -8.4500     46.00      89.0       100.0
# 562                maceio  -9.6658  -35.7353     77.00      88.0         0.0
#
#      Wind Speed Country          Date
# 0          6.44      ZA  1.615329e+09
# 1         25.32      IS  1.615329e+09
# 2          5.01      NZ  1.615329e+09
# 3          5.75      PT  1.615329e+09
# 4         11.99      CO  1.615328e+09
# ..          ...     ...           ...
# 558        3.04      ET  1.615329e+09
# 559       12.66      JP  1.615329e+09
# 560        7.74      ML  1.615329e+09
# 561       11.01      IE  1.615329e+09
# 562        8.05      BR  1.615329e+09
#
# [563 rows x 9 columns]

# %%
city_not_found
# Out:
# ['tumannyy',
#  'taolanaro',
#  'meyungs',
#  'mys shmidta',
#  'sentyabrskiy',
#  'barentsburg',
#  'vaitupu',
#  'palabuhanratu',
#  'illoqqortoormiut',
#  'belushya guba',
#  'viligili',
#  'samusu',
#  'amderma',
#  'attawapiskat',
#  'umzimvubu',
#  'toliary',
#  'grand river south east',
#  'kollumerland',
#  'saleaula',
#  'armacao dos buzios',
#  'aflu',
#  'nguiu',
#  'scottsburgh',
#  'tarudant',
#  'sofiysk',
#  'gurgan',
#  'ayios kirikos',
#  'rolim de moura',
#  'tsihombe',
#  'karamay',
#  'chikoy',
#  'karaul',
#  'bilaua',
#  'safwah',
#  'solsvik',
#  'bababe',
#  'phan rang',
#  'zlatoustovsk',
#  'saryshagan',
#  'mentok',
#  'rawannawi',
#  'afgoye',
#  'mullaitivu',
#  'ijaki',
#  'nizhneyansk',
#  'felidhoo']

# %%
#create dataframe with count, mean, std, min, 25th percentile, 50th percentile, 75th percentile, and max.
col_list=["Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Date"]

weather_city_df_agg=pd.DataFrame({"count": weather_city_df[col_list].count(),
                                  "mean": weather_city_df[col_list].mean(),
                                  "std": weather_city_df[col_list].std(),
                                  "min": weather_city_df[col_list].min(),
                                  "25%": weather_city_df[col_list].quantile(q=0.25).tolist(),
                                  "50%": weather_city_df[col_list].quantile(q=0.5).tolist(),
                                  "75%": weather_city_df[col_list].quantile(q=0.75).tolist(),
                                  "max": weather_city_df[col_list].max()}).T
weather_city_df_agg
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000  563.000000
# mean    19.817391   14.364466   54.508224   70.484902   49.065719    8.263552
# std     33.086565   91.056517   28.168931   21.471102   39.075859    5.782217
# min    -54.800000 -179.166700  -30.840000    1.000000    0.000000    0.340000
# 25%     -7.408450  -68.283350   39.165000   60.000000    4.500000    4.000000
# 50%     22.678300   15.640100   64.400000   75.000000   42.000000    6.910000
# 75%     47.768800   91.612600   76.270000   87.000000   90.000000   11.260000
# max     78.218600  179.316700   91.850000  100.000000  100.000000   36.820000
#
#                Date
# count  5.630000e+02
# mean   1.615329e+09
# std    2.435559e+02
# min    1.615328e+09
# 25%    1.615329e+09
# 50%    1.615329e+09
# 75%    1.615329e+09
# max    1.615329e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_city_df["Humidity"].head(20)
# Out:
# 0      86.0
# 1      93.0
# 2      94.0
# 3      88.0
# 4      59.0
# 5      44.0
# 6      94.0
# 7      60.0
# 8      75.0
# 9      71.0
# 10     85.0
# 11     88.0
# 12     20.0
# 13     83.0
# 14     55.0
# 15     94.0
# 16     66.0
# 17     83.0
# 18     70.0
# 19    100.0
# Name: Humidity, dtype: float64

# %%
#  Get the indices of cities that have humidity over 100%.
index_bool = weather_city_df["Humidity"]>100
index_hum_over100 = [i for i in range(len(index_bool)-1) if index_bool[i]==True]
index_hum_over100
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# did not need to pass inplace. The method below preserves the data eitherway and passes clean_city_data for future work.
if len(index_hum_over100) > 0:
    clean_city_data = weather_city_df.drop(index_hum_over100).reset_index(drop=True)
else:
    clean_city_data = weather_city_df
clean_city_data
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             east london -33.0153   27.9116     71.73      86.0        98.0
# 1               grindavik  63.8424  -22.4338     33.80      93.0        90.0
# 2                 mataura -46.1927  168.8643     55.00      94.0       100.0
# 3    vila franca do campo  37.7167  -25.4333     59.00      88.0        75.0
# 4             santa marta  11.2408  -74.1990     86.00      59.0        88.0
# ..                    ...      ...       ...       ...       ...         ...
# 558                  dese  11.1333   39.6333     54.75      56.0         6.0
# 559                hirara  24.8000  125.2833     68.00      82.0        40.0
# 560             bafoulabe  13.8065  -10.8321     84.09      15.0         0.0
# 561             killybegs  54.6333   -8.4500     46.00      89.0       100.0
# 562                maceio  -9.6658  -35.7353     77.00      88.0         0.0
#
#      Wind Speed Country          Date
# 0          6.44      ZA  1.615329e+09
# 1         25.32      IS  1.615329e+09
# 2          5.01      NZ  1.615329e+09
# 3          5.75      PT  1.615329e+09
# 4         11.99      CO  1.615328e+09
# ..          ...     ...           ...
# 558        3.04      ET  1.615329e+09
# 559       12.66      JP  1.615329e+09
# 560        7.74      ML  1.615329e+09
# 561       11.01      IE  1.615329e+09
# 562        8.05      BR  1.615329e+09
#
# [563 rows x 9 columns]

# %%
#Statistics Summary Table for clean_city_data
#create dataframe with count, mean, std, min, 25th percentile, 50th percentile, 75th percentile, and max.
col_list=["Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Date"]

clean_city_data_agg=pd.DataFrame({"count": clean_city_data[col_list].count(),
                                  "mean": clean_city_data[col_list].mean(),
                                  "std": clean_city_data[col_list].std(),
                                  "min": clean_city_data[col_list].min(),
                                  "25%": clean_city_data[col_list].quantile(q=0.25).tolist(),
                                  "50%": clean_city_data[col_list].quantile(q=0.5).tolist(),
                                  "75%": clean_city_data[col_list].quantile(q=0.75).tolist(),
                                  "max": clean_city_data[col_list].max()}).T
clean_city_data_agg
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000  563.000000
# mean    19.817391   14.364466   54.508224   70.484902   49.065719    8.263552
# std     33.086565   91.056517   28.168931   21.471102   39.075859    5.782217
# min    -54.800000 -179.166700  -30.840000    1.000000    0.000000    0.340000
# 25%     -7.408450  -68.283350   39.165000   60.000000    4.500000    4.000000
# 50%     22.678300   15.640100   64.400000   75.000000   42.000000    6.910000
# 75%     47.768800   91.612600   76.270000   87.000000   90.000000   11.260000
# max     78.218600  179.316700   91.850000  100.000000  100.000000   36.820000
#
#                Date
# count  5.630000e+02
# mean   1.615329e+09
# std    2.435559e+02
# min    1.615328e+09
# 25%    1.615329e+09
# 50%    1.615329e+09
# 75%    1.615329e+09
# max    1.615329e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(x=clean_city_data["Lat"].tolist(),y=clean_city_data["Max Temp"].tolist())
plt.title("City Latitude vs. Max Temperature " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Max Temperature 03/09/21')

# %%
#expected output

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(x=clean_city_data["Lat"].tolist(),y=clean_city_data["Humidity"].tolist())
plt.title("City Latitude vs. Humidity " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity 03/09/21')

# %%
#expected output

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(x=clean_city_data["Lat"].tolist(),y=clean_city_data["Cloudiness"].tolist())
plt.title("City Latitude vs. Cloudiness " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Cloudiness 03/09/21')

# %%
#expected output

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(x=clean_city_data["Lat"].tolist(),y=clean_city_data["Wind Speed"].tolist())
plt.title("City Latitude vs. Wind Speed " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Wind Speed 03/09/21')

# %%
#expected output

# %% [markdown]
# ## Linear Regression

# %%
#Northern hemisphere is latitude greater than 0; Southern hemisphere is latitude less than 0.
#For this exercise, cities with latitude exactly zero will be ignored.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]>0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]>0]["Max Temp"].tolist())
plt.title("Northern Hemisphere - Max Temp vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Max Temp vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]<0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]<0]["Max Temp"].tolist())
plt.title("Southern Hemisphere - Max Temp vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Max Temp vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]>0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]>0]["Humidity"].tolist())
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Humidity (%) vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]<0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]<0]["Humidity"].tolist())
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Humidity (%) vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]>0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]>0]["Cloudiness"].tolist())
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Cloudiness (%) vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]<0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]<0]["Cloudiness"].tolist())
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Cloudiness (%) vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]>0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]>0]["Wind Speed"].tolist())
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere - Wind Speed (mph) vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(x=clean_city_data[clean_city_data["Lat"]<0]["Lat"].tolist(),\
            y=clean_city_data[clean_city_data["Lat"]<0]["Wind Speed"].tolist())
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude " + date.today().strftime("%m/%d/%y"))
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere - Wind Speed (mph) vs. Latitude 03/09/21')

# %%
#expected output
# Out:
# The r-value is: 0.017128274759839232
